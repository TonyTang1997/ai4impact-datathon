# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import xgboost as xgb
from xgboost import plot_importance, plot_tree
from sklearn.metrics import mean_squared_error, mean_absolute_error
from matplotlib import pyplot
plt.style.use('fivethirtyeight')

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    """Calculates MAPE given y_true and y_pred"""
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

cal = calendar()

# %%
data = pd.read_csv('PJM_Load_hourly.csv', index_col=[0], parse_dates=[0])

# %%
data = data.sort_index()

# %%
#data['PJM_Load_MW_mean_halfday'] = data['PJM_Load_MW'].rolling(12).mean()
data['PJM_Load_MW_mean_daily'] = data['PJM_Load_MW'].rolling(24).mean()
data['PJM_Load_MW_mean_weekly'] = data['PJM_Load_MW'].rolling(24*7).mean()
data['PJM_Load_MW_mean_monthly'] = data['PJM_Load_MW'].rolling(24*30).mean()

# %%
#data['PJM_Load_MW_std_halfday'] = data['PJM_Load_MW'].rolling(12).mean()
data['PJM_Load_MW_std_daily'] = data['PJM_Load_MW'].rolling(24).std()
data['PJM_Load_MW_std_weekly'] = data['PJM_Load_MW'].rolling(24*7).std()
data['PJM_Load_MW_std_monthly'] = data['PJM_Load_MW'].rolling(24*30).std()

# %%
data['date'] = data.index
data['hour'] = data['date'].dt.hour
data['dayofweek'] = data['date'].dt.dayofweek
#data['quarter'] = data['date'].dt.quarter
data['month'] = data['date'].dt.month
data['year'] = data['date'].dt.year 
data['dayofyear'] = data['date'].dt.dayofyear
data['dayofmonth'] = data['date'].dt.day
data['weekofyear'] = data['date'].dt.weekofyear
#data['day_night'] = data['date'].dt.strftime('%B %d, %Y, %r').str[-2:]
#data['is_holiday'] = data['date'].isin([d.date() for d in cal.holidays()])

# %%
data = data.drop(columns=['date'])

# %%
data.head(10)
# Out:
#                      PJM_Load_MW  PJM_Load_MW_mean_daily  \
# Datetime
# 1998-04-01 01:00:00      22259.0                     NaN
# 1998-04-01 02:00:00      21244.0                     NaN
# 1998-04-01 03:00:00      20651.0                     NaN
# 1998-04-01 04:00:00      20421.0                     NaN
# 1998-04-01 05:00:00      20713.0                     NaN
# 1998-04-01 06:00:00      22526.0                     NaN
# 1998-04-01 07:00:00      25772.0                     NaN
# 1998-04-01 08:00:00      28724.0                     NaN
# 1998-04-01 09:00:00      30075.0                     NaN
# 1998-04-01 10:00:00      30689.0                     NaN
#
#                      PJM_Load_MW_mean_weekly  PJM_Load_MW_mean_monthly  \
# Datetime
# 1998-04-01 01:00:00                      NaN                       NaN
# 1998-04-01 02:00:00                      NaN                       NaN
# 1998-04-01 03:00:00                      NaN                       NaN
# 1998-04-01 04:00:00                      NaN                       NaN
# 1998-04-01 05:00:00                      NaN                       NaN
# 1998-04-01 06:00:00                      NaN                       NaN
# 1998-04-01 07:00:00                      NaN                       NaN
# 1998-04-01 08:00:00                      NaN                       NaN
# 1998-04-01 09:00:00                      NaN                       NaN
# 1998-04-01 10:00:00                      NaN                       NaN
#
#                      PJM_Load_MW_std_daily  PJM_Load_MW_std_weekly  \
# Datetime
# 1998-04-01 01:00:00                    NaN                     NaN
# 1998-04-01 02:00:00                    NaN                     NaN
# 1998-04-01 03:00:00                    NaN                     NaN
# 1998-04-01 04:00:00                    NaN                     NaN
# 1998-04-01 05:00:00                    NaN                     NaN
# 1998-04-01 06:00:00                    NaN                     NaN
# 1998-04-01 07:00:00                    NaN                     NaN
# 1998-04-01 08:00:00                    NaN                     NaN
# 1998-04-01 09:00:00                    NaN                     NaN
# 1998-04-01 10:00:00                    NaN                     NaN
#
#                      PJM_Load_MW_std_monthly  hour  dayofweek  month  year  \
# Datetime
# 1998-04-01 01:00:00                      NaN     1          2      4  1998
# 1998-04-01 02:00:00                      NaN     2          2      4  1998
# 1998-04-01 03:00:00                      NaN     3          2      4  1998
# 1998-04-01 04:00:00                      NaN     4          2      4  1998
# 1998-04-01 05:00:00                      NaN     5          2      4  1998
# 1998-04-01 06:00:00                      NaN     6          2      4  1998
# 1998-04-01 07:00:00                      NaN     7          2      4  1998
# 1998-04-01 08:00:00                      NaN     8          2      4  1998
# 1998-04-01 09:00:00                      NaN     9          2      4  1998
# 1998-04-01 10:00:00                      NaN    10          2      4  1998
#
#                      dayofyear  dayofmonth  weekofyear
# Datetime
# 1998-04-01 01:00:00         91           1          14
# 1998-04-01 02:00:00         91           1          14
# 1998-04-01 03:00:00         91           1          14
# 1998-04-01 04:00:00         91           1          14
# 1998-04-01 05:00:00         91           1          14
# 1998-04-01 06:00:00         91           1          14
# 1998-04-01 07:00:00         91           1          14
# 1998-04-01 08:00:00         91           1          14
# 1998-04-01 09:00:00         91           1          14
# 1998-04-01 10:00:00         91           1          14

# %%
data['target'] = data['PJM_Load_MW'].shift(-5)

# %%
data
# Out:
#                      PJM_Load_MW  PJM_Load_MW_mean_daily  \
# Datetime
# 1998-04-01 01:00:00      22259.0                     NaN
# 1998-04-01 02:00:00      21244.0                     NaN
# 1998-04-01 03:00:00      20651.0                     NaN
# 1998-04-01 04:00:00      20421.0                     NaN
# 1998-04-01 05:00:00      20713.0                     NaN
# ...                          ...                     ...
# 2001-12-31 20:00:00      36392.0            32718.750000
# 2001-12-31 21:00:00      35082.0            32681.583333
# 2001-12-31 22:00:00      33890.0            32636.208333
# 2001-12-31 23:00:00      32590.0            32605.333333
# 2002-01-01 00:00:00      31569.0            32628.458333
#
#                      PJM_Load_MW_mean_weekly  PJM_Load_MW_mean_monthly  \
# Datetime
# 1998-04-01 01:00:00                      NaN                       NaN
# 1998-04-01 02:00:00                      NaN                       NaN
# 1998-04-01 03:00:00                      NaN                       NaN
# 1998-04-01 04:00:00                      NaN                       NaN
# 1998-04-01 05:00:00                      NaN                       NaN
# ...                                      ...                       ...
# 2001-12-31 20:00:00             31029.851190              29640.298611
# 2001-12-31 21:00:00             31055.065476              29649.791667
# 2001-12-31 22:00:00             31074.839286              29659.000000
# 2001-12-31 23:00:00             31091.940476              29668.531944
# 2002-01-01 00:00:00             31112.553571              29679.390278
#
#                      PJM_Load_MW_std_daily  PJM_Load_MW_std_weekly  \
# Datetime
# 1998-04-01 01:00:00                    NaN                     NaN
# 1998-04-01 02:00:00                    NaN                     NaN
# 1998-04-01 03:00:00                    NaN                     NaN
# 1998-04-01 04:00:00                    NaN                     NaN
# 1998-04-01 05:00:00                    NaN                     NaN
# ...                                    ...                     ...
# 2001-12-31 20:00:00            3009.060178             3648.132180
# 2001-12-31 21:00:00            2972.389888             3661.468182
# 2001-12-31 22:00:00            2943.970049             3667.786829
# 2001-12-31 23:00:00            2940.249866             3668.115662
# 2002-01-01 00:00:00            2929.352236             3660.958835
#
#                      PJM_Load_MW_std_monthly  hour  dayofweek  month  year  \
# Datetime
# 1998-04-01 01:00:00                      NaN     1          2      4  1998
# 1998-04-01 02:00:00                      NaN     2          2      4  1998
# 1998-04-01 03:00:00                      NaN     3          2      4  1998
# 1998-04-01 04:00:00                      NaN     4          2      4  1998
# 1998-04-01 05:00:00                      NaN     5          2      4  1998
# ...                                      ...   ...        ...    ...   ...
# 2001-12-31 20:00:00              4121.390260    20          0     12  2001
# 2001-12-31 21:00:00              4126.045636    21          0     12  2001
# 2001-12-31 22:00:00              4128.102546    22          0     12  2001
# 2001-12-31 23:00:00              4126.934080    23          0     12  2001
# 2002-01-01 00:00:00              4121.624383     0          1      1  2002
#
#                      dayofyear  dayofmonth  weekofyear   target
# Datetime
# 1998-04-01 01:00:00         91           1          14  22526.0
# 1998-04-01 02:00:00         91           1          14  25772.0
# 1998-04-01 03:00:00         91           1          14  28724.0
# 1998-04-01 04:00:00         91           1          14  30075.0
# 1998-04-01 05:00:00         91           1          14  30689.0
# ...                        ...         ...         ...      ...
# 2001-12-31 20:00:00        365          31           1      NaN
# 2001-12-31 21:00:00        365          31           1      NaN
# 2001-12-31 22:00:00        365          31           1      NaN
# 2001-12-31 23:00:00        365          31           1      NaN
# 2002-01-01 00:00:00          1           1           1      NaN
#
# [32896 rows x 15 columns]

# %%
data.dropna(axis=0, how='any', inplace=True)

# %%
split_date = '31-12-1999'
data_train = data.loc[data.index <= split_date].copy()
data_test = data.loc[data.index > split_date].copy()

# %%
X_train = data_train.drop(columns=['target','year','month'])
X_test = data_test.drop(columns=['target','year','month'])
y_train = data_train[['target']]
y_test = data_test[['target']]

# %%
from sklearn.preprocessing import StandardScaler
std = StandardScaler()
# Out:
# StandardScaler(copy=True, with_mean=True, with_std=True)

# %%
# Out:
# array([[21358.],
#        [20409.],
#        [19614.],
#        ...,
#        [31251.],
#        [29231.],
#        [26633.]])

# %%
new_total_data_set = data_train
total_training_x = new_total_data_set["PJM_Load_MW"]
std.fit(np.array(total_training_x).reshape(-1,1))
new_total_data_set = std.fit_transform(new_total_data_set)
new_total_data_set.column = data_train.index
standardized_X_train = new_total_data_set.drop(columns=['target','year','month'])
standardized_X_test = new_total_data_set.drop(columns=['target','year','month'])
standardized_y_train = new_total_data_set[['target']]
standardized_y_test = new_total_data_set[['target']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-70-2cfa062912fd> in <module>
#       3 std.fit(np.array(total_training_x).reshape(-1,1))
#       4 new_total_data_set = std.fit_transform(new_total_data_set)
# ----> 5 new_total_data_set.column = data_train.index
#       6 standardized_X_train = new_total_data_set.drop(columns=['target','year','month'])
#       7 standardized_X_test = new_total_data_set.drop(columns=['target','year','month'])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'column'

# %%
standardized_X_train
# Out:
#                      PJM_Load_MW  PJM_Load_MW_mean_daily  \
# Datetime
# 1998-05-01 01:00:00      21358.0            26357.625000
# 1998-05-01 02:00:00      20409.0            26366.625000
# 1998-05-01 03:00:00      19614.0            26367.791667
# 1998-05-01 04:00:00      19432.0            26370.000000
# 1998-05-01 05:00:00      19822.0            26373.125000
# ...                          ...                     ...
# 1999-12-30 20:00:00      33276.0            30401.208333
# 1999-12-30 21:00:00      32588.0            30265.000000
# 1999-12-30 22:00:00      31251.0            30126.583333
# 1999-12-30 23:00:00      29231.0            30010.583333
# 1999-12-31 00:00:00      26633.0            29891.458333
#
#                      PJM_Load_MW_mean_weekly  PJM_Load_MW_mean_monthly  \
# Datetime
# 1998-05-01 01:00:00             25165.577381              25421.022222
# 1998-05-01 02:00:00             25163.922619              25418.452778
# 1998-05-01 03:00:00             25160.666667              25416.188889
# 1998-05-01 04:00:00             25157.053571              25414.495833
# 1998-05-01 05:00:00             25153.255952              25413.663889
# ...                                      ...                       ...
# 1999-12-30 20:00:00             30858.113095              30040.841667
# 1999-12-30 21:00:00             30843.476190              30035.484722
# 1999-12-30 22:00:00             30826.851190              30030.343056
# 1999-12-30 23:00:00             30808.982143              30025.981944
# 1999-12-31 00:00:00             30790.119048              30021.750000
#
#                      PJM_Load_MW_std_daily  PJM_Load_MW_std_weekly  \
# Datetime
# 1998-05-01 01:00:00            3919.814568             3710.523792
# 1998-05-01 02:00:00            3905.265997             3712.594449
# 1998-05-01 03:00:00            3903.155880             3717.245242
# 1998-05-01 04:00:00            3899.042658             3722.544438
# 1998-05-01 05:00:00            3893.529832             3727.686795
# ...                                    ...                     ...
# 1999-12-30 20:00:00            3051.227864             3367.556136
# 1999-12-30 21:00:00            2864.330364             3354.559214
# 1999-12-30 22:00:00            2723.923368             3345.511396
# 1999-12-30 23:00:00            2699.174220             3345.973010
# 1999-12-31 00:00:00            2784.787994             3360.584713
#
#                      PJM_Load_MW_std_monthly  hour  dayofweek  dayofyear  \
# Datetime
# 1998-05-01 01:00:00              3721.023518     1          4        121
# 1998-05-01 02:00:00              3723.847657     2          4        121
# 1998-05-01 03:00:00              3726.883255     3          4        121
# 1998-05-01 04:00:00              3729.327088     4          4        121
# 1998-05-01 05:00:00              3730.509220     5          4        121
# ...                                      ...   ...        ...        ...
# 1999-12-30 20:00:00              4176.604484    20          3        364
# 1999-12-30 21:00:00              4170.848581    21          3        364
# 1999-12-30 22:00:00              4167.058141    22          3        364
# 1999-12-30 23:00:00              4166.248110    23          3        364
# 1999-12-31 00:00:00              4168.147128     0          4        365
#
#                      dayofmonth  weekofyear
# Datetime
# 1998-05-01 01:00:00           1          18
# 1998-05-01 02:00:00           1          18
# 1998-05-01 03:00:00           1          18
# 1998-05-01 04:00:00           1          18
# 1998-05-01 05:00:00           1          18
# ...                         ...         ...
# 1999-12-30 20:00:00          30          52
# 1999-12-30 21:00:00          30          52
# 1999-12-30 22:00:00          30          52
# 1999-12-30 23:00:00          30          52
# 1999-12-31 00:00:00          31          52
#
# [14613 rows x 12 columns]

# %%
reg = xgb.XGBRegressor(n_estimators=100)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        early_stopping_rounds=50,
       verbose=True) # Change verbose to True if you want to see it train
# Out:
# [0]	validation_0-rmse:21128.38477	validation_1-rmse:21657.93164
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 50 rounds.
# [1]	validation_0-rmse:14882.31738	validation_1-rmse:15330.00586
# [2]	validation_0-rmse:10519.58496	validation_1-rmse:10902.10254
# [3]	validation_0-rmse:7486.73535	validation_1-rmse:7841.67188
# [4]	validation_0-rmse:5385.09668	validation_1-rmse:5720.71631
# [5]	validation_0-rmse:3952.22412	validation_1-rmse:4279.01172
# [6]	validation_0-rmse:2986.51294	validation_1-rmse:3314.32788
# [7]	validation_0-rmse:2333.27759	validation_1-rmse:2671.89551
# [8]	validation_0-rmse:1923.21899	validation_1-rmse:2285.82935
# [9]	validation_0-rmse:1643.71777	validation_1-rmse:2013.79187
# [10]	validation_0-rmse:1471.96326	validation_1-rmse:1856.53943
# [11]	validation_0-rmse:1371.80591	validation_1-rmse:1769.30798
# [12]	validation_0-rmse:1307.07654	validation_1-rmse:1727.25342
# [13]	validation_0-rmse:1259.99280	validation_1-rmse:1691.62256
# [14]	validation_0-rmse:1227.52173	validation_1-rmse:1664.66882
# [15]	validation_0-rmse:1205.63940	validation_1-rmse:1652.35840
# [16]	validation_0-rmse:1173.06934	validation_1-rmse:1639.10791
# [17]	validation_0-rmse:1142.35559	validation_1-rmse:1626.09619
# [18]	validation_0-rmse:1125.59814	validation_1-rmse:1633.04077
# [19]	validation_0-rmse:1083.69287	validation_1-rmse:1614.59070
# [20]	validation_0-rmse:1069.36914	validation_1-rmse:1602.32764
# [21]	validation_0-rmse:1057.04981	validation_1-rmse:1601.08081
# [22]	validation_0-rmse:1026.05823	validation_1-rmse:1596.07605
# [23]	validation_0-rmse:998.80298	validation_1-rmse:1594.43481
# [24]	validation_0-rmse:984.70551	validation_1-rmse:1595.89038
# [25]	validation_0-rmse:966.73682	validation_1-rmse:1582.43213
# [26]	validation_0-rmse:955.27136	validation_1-rmse:1578.50000
# [27]	validation_0-rmse:944.67175	validation_1-rmse:1593.37231
# [28]	validation_0-rmse:931.51294	validation_1-rmse:1600.78540
# [29]	validation_0-rmse:918.11383	validation_1-rmse:1595.08179
# [30]	validation_0-rmse:908.17993	validation_1-rmse:1597.18420
# [31]	validation_0-rmse:898.29657	validation_1-rmse:1596.30908
# [32]	validation_0-rmse:885.36627	validation_1-rmse:1599.55640
# [33]	validation_0-rmse:878.33606	validation_1-rmse:1604.55273
# [34]	validation_0-rmse:875.52374	validation_1-rmse:1610.76318
# [35]	validation_0-rmse:866.51404	validation_1-rmse:1637.66211
# [36]	validation_0-rmse:859.50507	validation_1-rmse:1634.21814
# [37]	validation_0-rmse:853.79474	validation_1-rmse:1647.40918
# [38]	validation_0-rmse:844.80951	validation_1-rmse:1644.98157
# [39]	validation_0-rmse:838.13873	validation_1-rmse:1645.48962
# [40]	validation_0-rmse:832.28790	validation_1-rmse:1642.14978
# [41]	validation_0-rmse:824.29791	validation_1-rmse:1641.99426
# [42]	validation_0-rmse:822.19550	validation_1-rmse:1641.59814
# [43]	validation_0-rmse:818.04077	validation_1-rmse:1641.48706
# [44]	validation_0-rmse:801.60052	validation_1-rmse:1628.99390
# [45]	validation_0-rmse:794.18848	validation_1-rmse:1634.18738
# [46]	validation_0-rmse:787.54010	validation_1-rmse:1634.49902
# [47]	validation_0-rmse:784.87549	validation_1-rmse:1634.70459
# [48]	validation_0-rmse:780.37280	validation_1-rmse:1634.83533
# [49]	validation_0-rmse:772.78699	validation_1-rmse:1635.31775
# [50]	validation_0-rmse:764.83411	validation_1-rmse:1638.98230
# [51]	validation_0-rmse:761.35101	validation_1-rmse:1639.48633
# [52]	validation_0-rmse:750.56366	validation_1-rmse:1643.59900
# [53]	validation_0-rmse:739.26697	validation_1-rmse:1626.96960
# [54]	validation_0-rmse:732.85571	validation_1-rmse:1643.56592
# [55]	validation_0-rmse:725.42371	validation_1-rmse:1644.70349
# [56]	validation_0-rmse:721.75275	validation_1-rmse:1645.32996
# [57]	validation_0-rmse:720.49500	validation_1-rmse:1645.57410
# [58]	validation_0-rmse:709.66577	validation_1-rmse:1646.20349
# [59]	validation_0-rmse:707.15668	validation_1-rmse:1646.87268
# [60]	validation_0-rmse:695.50696	validation_1-rmse:1648.67188
# [61]	validation_0-rmse:686.37518	validation_1-rmse:1648.01318
# [62]	validation_0-rmse:683.78607	validation_1-rmse:1649.38184
# [63]	validation_0-rmse:678.52515	validation_1-rmse:1649.70972
# [64]	validation_0-rmse:672.32617	validation_1-rmse:1650.73364
# [65]	validation_0-rmse:670.78870	validation_1-rmse:1650.29126
# [66]	validation_0-rmse:668.74847	validation_1-rmse:1650.37500
# [67]	validation_0-rmse:663.45068	validation_1-rmse:1650.93799
# [68]	validation_0-rmse:662.59906	validation_1-rmse:1650.95898
# [69]	validation_0-rmse:660.57257	validation_1-rmse:1650.67883
# [70]	validation_0-rmse:656.75769	validation_1-rmse:1650.08057
# [71]	validation_0-rmse:650.44861	validation_1-rmse:1648.79761
# [72]	validation_0-rmse:647.59082	validation_1-rmse:1648.57983
# [73]	validation_0-rmse:646.17645	validation_1-rmse:1648.20215
# [74]	validation_0-rmse:643.09302	validation_1-rmse:1650.29309
# [75]	validation_0-rmse:634.85590	validation_1-rmse:1651.02917
# [76]	validation_0-rmse:631.87280	validation_1-rmse:1651.40002
# Stopping. Best iteration:
# [26]	validation_0-rmse:955.27136	validation_1-rmse:1578.50000
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
pyplot.rcParams["figure.figsize"] = (20,10)

# %%
# retrieve performance metrics
results = reg.evals_result()
epochs = len(results['validation_0']['rmse'])
x_axis = range(0, epochs)
# plot rmse
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['rmse'], label='Train')
ax.plot(x_axis, results['validation_1']['rmse'], label='Test')
ax.legend()
pyplot.ylabel('RMSE')
pyplot.title('XGBoost RMSE')
pyplot.show()

# %%
_ = plot_importance(reg, height=0.9)

# %%
data_test['MW_Prediction'] = reg.predict(X_test)
data_all = pd.concat([data_test, data_train], sort=False)

# %%
#persistance error

# %%
mean_squared_error(y_true=data_test['PJM_Load_MW'],y_pred=data_test['MW_Prediction'])
# Out:
# 30483866.3359838

# %%
mean_absolute_error(y_true=data_test['PJM_Load_MW'],y_pred=data_test['MW_Prediction'])
# Out:
# 4422.525243687354

# %%
mean_absolute_percentage_error(y_true=data_test['PJM_Load_MW'],y_pred=data_test['MW_Prediction'])
# Out:
# 15.278173582442106

# %%
#predictions error

# %%
mean_squared_error(y_true=data_test['target'],y_pred=data_test['MW_Prediction'])
# Out:
# 2491663.953385091

# %%
mean_absolute_error(y_true=data_test['target'],y_pred=data_test['MW_Prediction'])
# Out:
# 1136.50991434236

# %%
mean_absolute_percentage_error(y_true=data_test['target'],y_pred=data_test['MW_Prediction'])
# Out:
# 3.6739215849622164

# %%
data_test['error'] = data_test['target'] - data_test['MW_Prediction']
data_test['abs_error'] = data_test['error'].apply(np.abs)
error_by_day = data_test.groupby(['year','month','dayofmonth']) \
    .mean()[['target','MW_Prediction','error','abs_error']]

# %%
# Over forecasted days
error_by_day.sort_values('error', ascending=True).head(20)
# Out:
#                              target  MW_Prediction        error    abs_error
# year month dayofmonth
# 2000 6     3           26445.041667   30750.351562 -4305.309408  4305.309408
#      7     19          30283.666667   33849.023438 -3565.357422  3739.976074
# 2001 9     1           29106.958333   31989.212891 -2882.255290  2888.151449
#      11    22          24753.875000   27424.673828 -2670.798747  3370.698649
# 2000 6     13          29479.541667   31889.751953 -2410.210531  2653.950602
# 2001 5     28          23556.333333   25943.109375 -2386.775309  2690.066325
# 2000 5     29          22638.625000   24964.988281 -2326.363851  2716.383382
# 2001 7     2           28495.166667   30754.753906 -2259.587646  2342.758057
# 2000 7     11          34255.208333   36433.316406 -2178.106364  2202.956136
#      6     12          35993.958333   38139.695312 -2145.736979  2230.886719
# 2001 5     5           26445.666667   28524.898438 -2079.232503  2096.452393
#      7     1           33254.833333   35273.339844 -2018.506348  2084.930013
# 2000 11    23          28447.416667   30347.671875 -1900.255127  3475.260498
#      5     15          27046.666667   28861.564453 -1814.897624  1909.538249
# 2001 7     18          34885.083333   36681.597656 -1796.515137  1916.589518
#      9     2           24748.375000   26522.533203 -1774.158854  1774.158854
#      12    24          27784.708333   29517.060547 -1732.352865  2543.485026
#      9     5           31508.666667   33220.621094 -1711.955160  1753.534261
# 2000 5     10          31256.083333   32933.183594 -1677.099365  1852.146891
# 2001 9     25          29115.750000   30758.667969 -1642.918864  1768.918538

# %%
_ = data_test[['target','MW_Prediction']].plot(figsize=(15, 5))

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = data_test[['MW_Prediction','target']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='01-01-2000', upper='02-01-2000')
ax.set_ylim(0, 60000)
plot = plt.suptitle('January 2000 Forecast vs Actuals')

# %%
# Plot the forecast with the actuals
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = data_test[['MW_Prediction','target']].plot(ax=ax,
                                              style=['-','.'])
ax.set_xbound(lower='09-01-2000', upper='09-30-2000')
ax.set_ylim(0, 60000)
plot = plt.suptitle('September 2000 Forecast vs Actuals')

# %%
f, ax = plt.subplots(1)
f.set_figheight(5)
f.set_figwidth(15)
_ = data_test[['MW_Prediction','target']].plot(ax=ax,
                                              style=['-','.'])
ax.set_ylim(0, 60000)
ax.set_xbound(lower='07-01-2000', upper='07-08-2000')
plot = plt.suptitle('First Week of July Forecast vs Actuals')
